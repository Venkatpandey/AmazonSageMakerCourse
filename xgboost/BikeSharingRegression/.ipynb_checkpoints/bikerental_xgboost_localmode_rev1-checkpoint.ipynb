# %% [markdown]
# ## Train a model with bike rental data using XGBoost algorithm
# ###  Model is trained with XGBoost installed in notebook instance
# ###  In the later examples, we will train using SageMaker's XGBoost algorithm

# %%
# Install xgboost in notebook instance.
#### Command to install xgboost
# !pip install xgboost==1.2
# Out:
# Requirement already satisfied: xgboost==1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (1.2.0)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from xgboost==1.2) (1.5.3)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from xgboost==1.2) (1.19.5)

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error

# XGBoost 
import xgboost as xgb

# %%
column_list_file = 'bike_train_column_list.txt'
train_file = 'bike_train.csv'
validation_file = 'bike_validation.csv'
test_file = 'bike_test.csv'

# %%
columns = ''
with open(column_list_file,'r') as f:
    columns = f.read().split(',')

# %%
columns
# Out:
# ['count',
#  'season',
#  'holiday',
#  'workingday',
#  'weather',
#  'temp',
#  'atemp',
#  'humidity',
#  'windspeed',
#  'year',
#  'month',
#  'day',
#  'dayofweek',
#  'hour']

# %%
# Specify the column names as the file does not have column header
df_train = pd.read_csv(train_file,names=columns)
df_validation = pd.read_csv(validation_file,names=columns)

# %%
df_train.head()
# Out:
#    count  season  holiday  workingday  weather   temp   atemp  humidity  \
# 0     87       3        0           0        2  26.24  30.305        73
# 1    248       3        0           1        1  32.80  34.850        33
# 2    334       4        0           0        1  15.58  19.695        40
# 3    623       3        0           1        1  32.80  37.880        55
# 4     70       2        0           1        1  13.94  17.425        76
#
#    windspeed  year  month  day  dayofweek  hour
# 0     7.0015  2011      9    3          5     0
# 1     7.0015  2012      8   13          0    14
# 2    11.0014  2011     11    5          5    17
# 3    12.9980  2012      8    9          3    19
# 4     7.0015  2011      4   14          3     6

# %%
df_validation.head()
# Out:
#    count  season  holiday  workingday  weather   temp   atemp  humidity  \
# 0    443       3        0           1        2  28.70  33.335        79
# 1    387       2        0           0        1  32.80  37.880        55
# 2      2       1        0           1        1  14.76  16.665        40
# 3     48       1        0           1        1   9.02   9.090        47
# 4     55       4        0           0        1  10.66  15.150        87
#
#    windspeed  year  month  day  dayofweek  hour
# 0    12.9980  2011      7    7          3     8
# 1    12.9980  2011      6   11          5    13
# 2    19.9995  2011      2   14          0     2
# 3    36.9974  2011      2    8          1    10
# 4     0.0000  2011     12    4          6     8

# %%
X_train = df_train.iloc[:,1:] # Features: 1st column onwards 
y_train = df_train.iloc[:,0].ravel() # Target: 0th column

X_validation = df_validation.iloc[:,1:]
y_validation = df_validation.iloc[:,0].ravel()

# %%
# XGBoost Training Parameter Reference: 
#   https://github.com/dmlc/xgboost/blob/master/doc/parameter.md
#regressor = xgb.XGBRegressor(max_depth=5,eta=0.1,subsample=0.7,num_round=150)
regressor = xgb.XGBRegressor(max_depth=5,n_estimators=150)

# %%
regressor
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=None, gamma=None,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=None, max_delta_step=None, max_depth=5,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=150, n_jobs=None, num_parallel_tree=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=None)

# %%
regressor.fit(X_train,y_train, eval_set = [(X_train, y_train), (X_validation, y_validation)])
# Out:
# [0]	validation_0-rmse:200.21237	validation_1-rmse:198.50748
# [1]	validation_0-rmse:158.44937	validation_1-rmse:156.82236
# [2]	validation_0-rmse:130.70624	validation_1-rmse:129.74681
# [3]	validation_0-rmse:113.91985	validation_1-rmse:113.36162
# [4]	validation_0-rmse:97.49922	validation_1-rmse:97.96387
# [5]	validation_0-rmse:84.68189	validation_1-rmse:86.42601
# [6]	validation_0-rmse:75.20274	validation_1-rmse:77.72005
# [7]	validation_0-rmse:71.41850	validation_1-rmse:74.25261
# [8]	validation_0-rmse:64.23003	validation_1-rmse:67.80524
# [9]	validation_0-rmse:61.86999	validation_1-rmse:65.64179
# [10]	validation_0-rmse:60.00383	validation_1-rmse:63.93544
# [11]	validation_0-rmse:57.38253	validation_1-rmse:61.66848
# [12]	validation_0-rmse:55.40469	validation_1-rmse:59.70895
# [13]	validation_0-rmse:53.46251	validation_1-rmse:58.07008
# [14]	validation_0-rmse:50.16571	validation_1-rmse:55.00782
# [15]	validation_0-rmse:49.58625	validation_1-rmse:54.48377
# [16]	validation_0-rmse:49.10565	validation_1-rmse:53.95740
# [17]	validation_0-rmse:46.31592	validation_1-rmse:51.42872
# [18]	validation_0-rmse:45.25656	validation_1-rmse:50.72695
# [19]	validation_0-rmse:44.66090	validation_1-rmse:50.27215
# [20]	validation_0-rmse:43.69100	validation_1-rmse:49.51649
# [21]	validation_0-rmse:43.06360	validation_1-rmse:49.09360
# [22]	validation_0-rmse:42.79749	validation_1-rmse:48.97206
# [23]	validation_0-rmse:42.22981	validation_1-rmse:48.57885
# [24]	validation_0-rmse:42.07682	validation_1-rmse:48.46536
# [25]	validation_0-rmse:41.79094	validation_1-rmse:48.40559
# [26]	validation_0-rmse:40.22366	validation_1-rmse:47.06445
# [27]	validation_0-rmse:40.02082	validation_1-rmse:46.96824
# [28]	validation_0-rmse:39.61360	validation_1-rmse:46.72801
# [29]	validation_0-rmse:39.32627	validation_1-rmse:46.58315
# [30]	validation_0-rmse:39.17387	validation_1-rmse:46.47925
# [31]	validation_0-rmse:38.45698	validation_1-rmse:46.02085
# [32]	validation_0-rmse:38.15527	validation_1-rmse:45.90459
# [33]	validation_0-rmse:37.93132	validation_1-rmse:45.77934
# [34]	validation_0-rmse:37.61134	validation_1-rmse:45.62778
# [35]	validation_0-rmse:37.41719	validation_1-rmse:45.47066
# [36]	validation_0-rmse:37.33950	validation_1-rmse:45.43343
# [37]	validation_0-rmse:36.62578	validation_1-rmse:44.90997
# [38]	validation_0-rmse:36.42527	validation_1-rmse:44.84259
# [39]	validation_0-rmse:36.06162	validation_1-rmse:44.76580
# [40]	validation_0-rmse:35.93214	validation_1-rmse:44.74343
# [41]	validation_0-rmse:35.88740	validation_1-rmse:44.71637
# [42]	validation_0-rmse:35.50912	validation_1-rmse:44.60796
# [43]	validation_0-rmse:35.11190	validation_1-rmse:44.35005
# [44]	validation_0-rmse:35.00736	validation_1-rmse:44.29070
# [45]	validation_0-rmse:34.78140	validation_1-rmse:44.23080
# [46]	validation_0-rmse:34.73854	validation_1-rmse:44.23772
# [47]	validation_0-rmse:34.65159	validation_1-rmse:44.17048
# [48]	validation_0-rmse:34.35805	validation_1-rmse:44.09883
# [49]	validation_0-rmse:34.19989	validation_1-rmse:44.09992
# [50]	validation_0-rmse:34.14430	validation_1-rmse:44.11221
# [51]	validation_0-rmse:33.91167	validation_1-rmse:44.04287
# [52]	validation_0-rmse:33.74896	validation_1-rmse:44.04637
# [53]	validation_0-rmse:33.58469	validation_1-rmse:43.98733
# [54]	validation_0-rmse:33.51054	validation_1-rmse:43.98549
# [55]	validation_0-rmse:33.31728	validation_1-rmse:44.02943
# [56]	validation_0-rmse:33.23238	validation_1-rmse:44.02082
# [57]	validation_0-rmse:33.19658	validation_1-rmse:44.00652
# [58]	validation_0-rmse:33.07861	validation_1-rmse:43.99137
# [59]	validation_0-rmse:32.86804	validation_1-rmse:43.89019
# [60]	validation_0-rmse:32.72254	validation_1-rmse:43.82262
# [61]	validation_0-rmse:32.31545	validation_1-rmse:43.49293
# [62]	validation_0-rmse:32.29336	validation_1-rmse:43.46724
# [63]	validation_0-rmse:32.07835	validation_1-rmse:43.38681
# [64]	validation_0-rmse:31.90101	validation_1-rmse:43.32034
# [65]	validation_0-rmse:31.86056	validation_1-rmse:43.32325
# [66]	validation_0-rmse:31.70476	validation_1-rmse:43.18751
# [67]	validation_0-rmse:31.59031	validation_1-rmse:43.19709
# [68]	validation_0-rmse:31.39416	validation_1-rmse:43.18813
# [69]	validation_0-rmse:31.12864	validation_1-rmse:43.09849
# [70]	validation_0-rmse:31.07492	validation_1-rmse:43.09148
# [71]	validation_0-rmse:31.00556	validation_1-rmse:43.09359
# [72]	validation_0-rmse:30.87336	validation_1-rmse:43.00188
# [73]	validation_0-rmse:30.56048	validation_1-rmse:42.88081
# [74]	validation_0-rmse:30.48121	validation_1-rmse:42.82766
# [75]	validation_0-rmse:30.32722	validation_1-rmse:42.81790
# [76]	validation_0-rmse:30.23960	validation_1-rmse:42.79342
# [77]	validation_0-rmse:30.20228	validation_1-rmse:42.78965
# [78]	validation_0-rmse:29.99587	validation_1-rmse:42.77126
# [79]	validation_0-rmse:29.75669	validation_1-rmse:42.64365
# [80]	validation_0-rmse:29.66938	validation_1-rmse:42.59290
# [81]	validation_0-rmse:29.62374	validation_1-rmse:42.59439
# [82]	validation_0-rmse:29.50415	validation_1-rmse:42.54274
# [83]	validation_0-rmse:29.42191	validation_1-rmse:42.49807
# [84]	validation_0-rmse:29.36916	validation_1-rmse:42.49364
# [85]	validation_0-rmse:29.27201	validation_1-rmse:42.43840
# [86]	validation_0-rmse:29.13931	validation_1-rmse:42.42627
# [87]	validation_0-rmse:29.08374	validation_1-rmse:42.40068
# [88]	validation_0-rmse:29.02746	validation_1-rmse:42.39584
# [89]	validation_0-rmse:28.88186	validation_1-rmse:42.35032
# [90]	validation_0-rmse:28.75089	validation_1-rmse:42.28241
# [91]	validation_0-rmse:28.64257	validation_1-rmse:42.29661
# [92]	validation_0-rmse:28.51315	validation_1-rmse:42.24074
# [93]	validation_0-rmse:28.43576	validation_1-rmse:42.21894
# [94]	validation_0-rmse:28.34129	validation_1-rmse:42.23726
# [95]	validation_0-rmse:28.24364	validation_1-rmse:42.19882
# [96]	validation_0-rmse:28.14094	validation_1-rmse:42.15162
# [97]	validation_0-rmse:28.08991	validation_1-rmse:42.13849
# [98]	validation_0-rmse:28.05212	validation_1-rmse:42.12962
# [99]	validation_0-rmse:28.01991	validation_1-rmse:42.13131
# [100]	validation_0-rmse:27.97188	validation_1-rmse:42.12577
# [101]	validation_0-rmse:27.95016	validation_1-rmse:42.13953
# [102]	validation_0-rmse:27.84402	validation_1-rmse:42.10888
# [103]	validation_0-rmse:27.80202	validation_1-rmse:42.07974
# [104]	validation_0-rmse:27.79910	validation_1-rmse:42.08551
# [105]	validation_0-rmse:27.75463	validation_1-rmse:42.08252
# [106]	validation_0-rmse:27.62788	validation_1-rmse:42.08866
# [107]	validation_0-rmse:27.48359	validation_1-rmse:42.00879
# [108]	validation_0-rmse:27.31545	validation_1-rmse:41.93489
# [109]	validation_0-rmse:27.23284	validation_1-rmse:41.92241
# [110]	validation_0-rmse:27.09927	validation_1-rmse:41.90097
# [111]	validation_0-rmse:27.00992	validation_1-rmse:41.87125
# [112]	validation_0-rmse:27.00166	validation_1-rmse:41.87183
# [113]	validation_0-rmse:26.93702	validation_1-rmse:41.84039
# [114]	validation_0-rmse:26.80303	validation_1-rmse:41.80264
# [115]	validation_0-rmse:26.73493	validation_1-rmse:41.80722
# [116]	validation_0-rmse:26.64247	validation_1-rmse:41.77973
# [117]	validation_0-rmse:26.57824	validation_1-rmse:41.79134
# [118]	validation_0-rmse:26.46565	validation_1-rmse:41.71431
# [119]	validation_0-rmse:26.39325	validation_1-rmse:41.67694
# [120]	validation_0-rmse:26.37276	validation_1-rmse:41.68118
# [121]	validation_0-rmse:26.28281	validation_1-rmse:41.66747
# [122]	validation_0-rmse:26.19166	validation_1-rmse:41.64709
# [123]	validation_0-rmse:26.00081	validation_1-rmse:41.58642
# [124]	validation_0-rmse:25.85091	validation_1-rmse:41.59726
# [125]	validation_0-rmse:25.79181	validation_1-rmse:41.58296
# [126]	validation_0-rmse:25.68886	validation_1-rmse:41.61711
# [127]	validation_0-rmse:25.58066	validation_1-rmse:41.60252
# [128]	validation_0-rmse:25.52996	validation_1-rmse:41.56732
# [129]	validation_0-rmse:25.45470	validation_1-rmse:41.56769
# [130]	validation_0-rmse:25.39346	validation_1-rmse:41.54351
# [131]	validation_0-rmse:25.37823	validation_1-rmse:41.53870
# [132]	validation_0-rmse:25.24822	validation_1-rmse:41.49659
# [133]	validation_0-rmse:25.19883	validation_1-rmse:41.47297
# [134]	validation_0-rmse:25.12122	validation_1-rmse:41.47224
# [135]	validation_0-rmse:25.07266	validation_1-rmse:41.46833
# [136]	validation_0-rmse:25.01747	validation_1-rmse:41.44282
# [137]	validation_0-rmse:24.91434	validation_1-rmse:41.39120
# [138]	validation_0-rmse:24.90468	validation_1-rmse:41.39363
# [139]	validation_0-rmse:24.81353	validation_1-rmse:41.36809
# [140]	validation_0-rmse:24.78586	validation_1-rmse:41.36993
# [141]	validation_0-rmse:24.74157	validation_1-rmse:41.36147
# [142]	validation_0-rmse:24.62952	validation_1-rmse:41.32303
# [143]	validation_0-rmse:24.57400	validation_1-rmse:41.32358
# [144]	validation_0-rmse:24.51090	validation_1-rmse:41.28474
# [145]	validation_0-rmse:24.42650	validation_1-rmse:41.25938
# [146]	validation_0-rmse:24.39769	validation_1-rmse:41.25982
# [147]	validation_0-rmse:24.30933	validation_1-rmse:41.26104
# [148]	validation_0-rmse:24.20446	validation_1-rmse:41.19976
# [149]	validation_0-rmse:24.10521	validation_1-rmse:41.11282
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=5,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=150, n_jobs=0, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
eval_result = regressor.evals_result()

# %%
training_rounds = range(len(eval_result['validation_0']['rmse']))

# %%
print(training_rounds)
# Out:
# range(0, 150)

# %%
plt.scatter(x=training_rounds,y=eval_result['validation_0']['rmse'],label='Training Error')
plt.scatter(x=training_rounds,y=eval_result['validation_1']['rmse'],label='Validation Error')
plt.grid(True)
plt.xlabel('Iteration')
plt.ylabel('RMSE')
plt.title('Training Vs Validation Error')
plt.legend()
plt.show()

# %%
xgb.plot_importance(regressor)
plt.show()

# %%
# Verify Quality using Validation dataset
# Compare actual vs predicted performance with dataset not seen by the model before
df = pd.read_csv(validation_file,names=columns)

# %%
df.head()
# Out:
#    count  season  holiday  workingday  weather   temp   atemp  humidity  \
# 0    443       3        0           1        2  28.70  33.335        79
# 1    387       2        0           0        1  32.80  37.880        55
# 2      2       1        0           1        1  14.76  16.665        40
# 3     48       1        0           1        1   9.02   9.090        47
# 4     55       4        0           0        1  10.66  15.150        87
#
#    windspeed  year  month  day  dayofweek  hour
# 0    12.9980  2011      7    7          3     8
# 1    12.9980  2011      6   11          5    13
# 2    19.9995  2011      2   14          0     2
# 3    36.9974  2011      2    8          1    10
# 4     0.0000  2011     12    4          6     8

# %%
df.shape
# Out:
# (3266, 14)

# %%
X_test = df.iloc[:,1:]
print(X_test[:5])
# Out:
#    season  holiday  workingday  weather   temp   atemp  humidity  windspeed  \
# 0       3        0           1        2  28.70  33.335        79    12.9980
# 1       2        0           0        1  32.80  37.880        55    12.9980
# 2       1        0           1        1  14.76  16.665        40    19.9995
# 3       1        0           1        1   9.02   9.090        47    36.9974
# 4       4        0           0        1  10.66  15.150        87     0.0000
#
#    year  month  day  dayofweek  hour
# 0  2011      7    7          3     8
# 1  2011      6   11          5    13
# 2  2011      2   14          0     2
# 3  2011      2    8          1    10
# 4  2011     12    4          6     8

# %%
result = regressor.predict(X_test)

# %%
result[:5]
# Out:
# array([452.154     , 373.7294    ,   0.75503814,  64.58523   ,
#         83.32642   ], dtype=float32)

# %%
df['count_predicted'] = result

# %%
df.head()
# Out:
#    count  season  holiday  workingday  weather   temp   atemp  humidity  \
# 0    443       3        0           1        2  28.70  33.335        79
# 1    387       2        0           0        1  32.80  37.880        55
# 2      2       1        0           1        1  14.76  16.665        40
# 3     48       1        0           1        1   9.02   9.090        47
# 4     55       4        0           0        1  10.66  15.150        87
#
#    windspeed  year  month  day  dayofweek  hour  count_predicted
# 0    12.9980  2011      7    7          3     8       452.153992
# 1    12.9980  2011      6   11          5    13       373.729401
# 2    19.9995  2011      2   14          0     2         0.755038
# 3    36.9974  2011      2    8          1    10        64.585228
# 4     0.0000  2011     12    4          6     8        83.326424

# %%
# Negative Values are predicted
df['count_predicted'].describe()
# Out:
# count    3266.000000
# mean      190.070694
# std       174.655899
# min       -95.306847
# 25%        43.720430
# 50%       150.537590
# 75%       284.134521
# max       901.711853
# Name: count_predicted, dtype: float64

# %%
df[df['count_predicted'] < 0]
# Out:
#       count  season  holiday  workingday  weather   temp   atemp  humidity  \
# 99       71       2        0           1        3  22.96  26.515        88
# 103      11       3        0           1        2  27.88  31.820        83
# 117       2       4        0           1        1   8.20  12.880        80
# 137       9       1        0           1        1  15.58  19.695        54
# 158      45       1        0           0        2  12.30  13.635       100
# ...     ...     ...      ...         ...      ...    ...     ...       ...
# 3129     44       1        0           1        3  13.12  16.665        70
# 3176     16       4        0           1        2  12.30  14.395        52
# 3199      8       4        0           1        1  13.94  15.910        81
# 3252     11       3        0           0        1  25.42  30.305        61
# 3259      4       1        0           1        1   8.20  12.880        61
#
#       windspeed  year  month  day  dayofweek  hour  count_predicted
# 99       7.0015  2012      5   15          1    23        -1.970796
# 103     12.9980  2012      8   14          1     2        -6.368350
# 117      0.0000  2011     12   13          1     2        -2.282263
# 137      7.0015  2012      3   12          0     2        -6.041609
# 158     19.9995  2011      3    5          5     8       -13.944295
# ...         ...   ...    ...  ...        ...   ...              ...
# 3129     8.9981  2012      2   16          3    10        -5.859625
# 3176    16.9979  2012     11    5          0     4        -2.210039
# 3199    15.0013  2011     11    1          1     4        -1.095655
# 3252     0.0000  2011      7    2          5     4        -1.057944
# 3259     0.0000  2012      1    5          3     3        -2.007123
#
# [127 rows x 15 columns]

# %%
df['count_predicted'].hist()
plt.title('Predicted Count Histogram')
plt.show()

# %%
def adjust_count(x):
    if x < 0:
        return 0
    else:
        return x

# %%
df['count_predicted'] = df['count_predicted'].map(adjust_count)

# %%
df[df['count_predicted'] < 0]
# Out:
# Empty DataFrame
# Columns: [count, season, holiday, workingday, weather, temp, atemp, humidity, windspeed, year, month, day, dayofweek, hour, count_predicted]
# Index: []

# %%
# Actual Vs Predicted
plt.plot(df['count'], label='Actual')
plt.plot(df['count_predicted'],label='Predicted')
plt.xlabel('Sample')
plt.ylabel('Count')
plt.xlim([100,150])
plt.title('Validation Dataset - Predicted Vs. Actual')
plt.legend()
plt.show()

# %%
# Over prediction and Under Prediction needs to be balanced
# Training Data Residuals
residuals = (df['count'] - df['count_predicted'])

plt.hist(residuals)
plt.grid(True)
plt.xlabel('Actual - Predicted')
plt.ylabel('Count')
plt.title('Residuals Distribution')
plt.axvline(color='r')
plt.show()

# %%
value_counts = (residuals > 0).value_counts(sort=False)
print(' Under Estimation: {0:0.2f}'.format(value_counts[True]/len(residuals)))
print(' Over  Estimation: {0:0.2f}'.format(value_counts[False]/len(residuals)))
# Out:
#  Under Estimation: 0.48
#  Over  Estimation: 0.52

# %%
print("RMSE: {0:0.2f}".format(mean_squared_error(df['count'],df['count_predicted'])**.5))
# Out:
# RMSE: 43.68

# %%
# RMSlE - Root Mean Squared Log Error
# RMSLE Metric is used by Kaggle for this competition

# RMSE Cost Function - Magnitude of difference matters

# RMSLE cost function - "Only Percentage difference matters"

# Reference:Katerina Malahova, Khor SoonHin 
# https://www.slideshare.net/KhorSoonHin/rmsle-cost-function
def compute_rmsle(y_true, y_pred):
    if type(y_true) != np.ndarray:
        y_true = np.array(y_true)
        
    if type(y_pred) != np.ndarray:
        y_pred = np.array(y_pred)
     
    return(np.average((np.log1p(y_pred) - np.log1p(y_true))**2)**.5)

# %%
print('RMSLE')
print(compute_rmsle(100,50),
      compute_rmsle(1000,500),
      compute_rmsle(10000,5000))
# Out:
# RMSLE
# 0.683294884116934 0.6921486782303559 0.6930471955576127

# %%
print('RMSLE')
print(compute_rmsle(100,25),
      compute_rmsle(1000,250),
      compute_rmsle(10000,2500))
# Out:
# RMSLE
# 1.3570239788197775 1.383301840183437 1.3859944360988976

# %%
print('RMSE')
print(mean_squared_error([100],[50])**.5,
      mean_squared_error([1000],[500])**.5, 
      mean_squared_error([10000],[5000])**.5)
# Out:
# RMSE
# 50.0 500.0 5000.0

# %%
print('RMSE')
print(mean_squared_error([100],[25])**.5,
      mean_squared_error([1000],[250])**.5, 
      mean_squared_error([10000],[2500])**.5)
# Out:
# RMSE
# 75.0 750.0 7500.0

# %%
print("RMSLE: {0}".format(compute_rmsle(df['count'],df['count_predicted'])))
# Out:
# RMSLE: 0.49787719339339304

# %%
# Prepare Data for Submission to Kaggle
df_test = pd.read_csv(test_file,parse_dates=['datetime'])

# %%
df_test.head()
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  year  month  day  dayofweek  hour
# 0        56    26.0027  2011      1   20          3     0
# 1        56     0.0000  2011      1   20          3     1
# 2        56     0.0000  2011      1   20          3     2
# 3        56    11.0014  2011      1   20          3     3
# 4        56    11.0014  2011      1   20          3     4

# %%
X_test =  df_test.iloc[:,1:] # Exclude datetime for prediction

# %%
X_test.head()
# Out:
#    season  holiday  workingday  weather   temp   atemp  humidity  windspeed  \
# 0       1        0           1        1  10.66  11.365        56    26.0027
# 1       1        0           1        1  10.66  13.635        56     0.0000
# 2       1        0           1        1  10.66  13.635        56     0.0000
# 3       1        0           1        1  10.66  12.880        56    11.0014
# 4       1        0           1        1  10.66  12.880        56    11.0014
#
#    year  month  day  dayofweek  hour
# 0  2011      1   20          3     0
# 1  2011      1   20          3     1
# 2  2011      1   20          3     2
# 3  2011      1   20          3     3
# 4  2011      1   20          3     4

# %%
result = regressor.predict(X_test)

# %%
result[:5]
# Out:
# array([10.033908 , -1.0149912, -5.805891 , -4.739464 , -4.739464 ],
#       dtype=float32)

# %%
df_test["count"] = result

# %%
df_test.head()
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  year  month  day  dayofweek  hour      count
# 0        56    26.0027  2011      1   20          3     0  10.033908
# 1        56     0.0000  2011      1   20          3     1  -1.014991
# 2        56     0.0000  2011      1   20          3     2  -5.805891
# 3        56    11.0014  2011      1   20          3     3  -4.739464
# 4        56    11.0014  2011      1   20          3     4  -4.739464

# %%
df_test[df_test["count"] < 0]
# Out:
#                 datetime  season  holiday  workingday  weather   temp   atemp  \
# 1    2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2    2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3    2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4    2011-01-20 04:00:00       1        0           1        1  10.66  12.880
# 25   2011-01-21 01:00:00       1        0           1        2   9.84  11.365
# 26   2011-01-21 02:00:00       1        0           1        3   9.84  12.120
# 27   2011-01-21 03:00:00       1        0           1        3   9.02  10.605
# 28   2011-01-21 04:00:00       1        0           1        2   9.02  12.880
# 52   2011-01-22 04:00:00       1        0           0        2   0.82   0.760
# 53   2011-01-22 06:00:00       1        0           0        2   0.82   1.515
# 54   2011-01-22 07:00:00       1        0           0        1   0.82   0.760
# 55   2011-01-22 08:00:00       1        0           0        1   0.82   0.000
# 74   2011-01-23 03:00:00       1        0           0        1   0.82   3.030
# 75   2011-01-23 05:00:00       1        0           0        2   1.64   3.790
# 76   2011-01-23 06:00:00       1        0           0        2   1.64   3.790
# 77   2011-01-23 07:00:00       1        0           0        1   3.28   5.305
# 78   2011-01-23 08:00:00       1        0           0        1   2.46   3.790
# 93   2011-01-23 23:00:00       1        0           0        1   2.46   3.030
# 95   2011-01-24 01:00:00       1        0           1        1   1.64   2.275
# 96   2011-01-24 03:00:00       1        0           1        1   1.64   1.515
# 97   2011-01-24 04:00:00       1        0           1        1   0.82   3.030
# 118  2011-01-25 01:00:00       1        0           1        2   6.56   8.335
# 119  2011-01-25 02:00:00       1        0           1        1   6.56   7.575
# 120  2011-01-25 04:00:00       1        0           1        1   5.74   8.335
# 141  2011-01-26 01:00:00       1        0           1        2   9.84  12.120
# 142  2011-01-26 02:00:00       1        0           1        3   9.02  11.365
# 148  2011-01-26 10:00:00       1        0           1        3   9.02  10.605
# 149  2011-01-26 11:00:00       1        0           1        3   9.02   9.850
# 150  2011-01-26 12:00:00       1        0           1        3   9.02   9.850
# 151  2011-01-26 13:00:00       1        0           1        3   9.02   9.850
# ...                  ...     ...      ...         ...      ...    ...     ...
# 3443 2012-01-29 04:00:00       1        0           0        1   9.84  12.880
# 3467 2012-01-30 04:00:00       1        0           1        1   8.20  10.605
# 3513 2012-02-20 02:00:00       1        1           0        2   9.84  12.880
# 3516 2012-02-20 06:00:00       1        1           0        1   9.84   9.850
# 3607 2012-02-24 02:00:00       1        0           1        3  17.22  21.210
# 3633 2012-02-25 04:00:00       1        0           0        1  12.30  13.635
# 4107 2012-04-22 23:00:00       2        0           0        3  14.76  15.910
# 4109 2012-04-23 01:00:00       2        0           1        3  13.94  15.150
# 4110 2012-04-23 02:00:00       2        0           1        2  13.12  15.150
# 4111 2012-04-23 03:00:00       2        0           1        2  13.12  15.150
# 4112 2012-04-23 04:00:00       2        0           1        3  12.30  14.395
# 4113 2012-04-23 05:00:00       2        0           1        3  12.30  14.395
# 4325 2012-05-21 01:00:00       2        0           1        3  23.78  27.275
# 4326 2012-05-21 02:00:00       2        0           1        3  22.96  26.515
# 4327 2012-05-21 03:00:00       2        0           1        2  22.96  26.515
# 4328 2012-05-21 04:00:00       2        0           1        3  22.96  26.515
# 4329 2012-05-21 05:00:00       2        0           1        3  22.96  26.515
# 4350 2012-05-22 02:00:00       2        0           1        2  23.78  27.275
# 4351 2012-05-22 03:00:00       2        0           1        2  23.78  27.275
# 4352 2012-05-22 04:00:00       2        0           1        2  22.96  26.515
# 4543 2012-05-30 03:00:00       2        0           1        3  25.42  28.030
# 5142 2012-08-20 02:00:00       3        0           1        1  24.60  28.030
# 5144 2012-08-20 04:00:00       3        0           1        2  24.60  28.030
# 5621 2012-09-28 01:00:00       4        0           1        3  24.60  27.275
# 5622 2012-09-28 02:00:00       4        0           1        3  24.60  27.275
# 5624 2012-09-28 04:00:00       4        0           1        3  22.96  26.515
# 5906 2012-10-28 22:00:00       4        0           0        3  18.04  21.970
# 5907 2012-10-28 23:00:00       4        0           0        3  17.22  21.210
# 6230 2012-12-20 23:00:00       4        0           1        3  16.40  20.455
# 6372 2012-12-26 23:00:00       1        0           1        3  10.66  11.365
#
#       humidity  windspeed  year  month  day  dayofweek  hour      count
# 1           56     0.0000  2011      1   20          3     1  -1.014991
# 2           56     0.0000  2011      1   20          3     2  -5.805891
# 3           56    11.0014  2011      1   20          3     3  -4.739464
# 4           56    11.0014  2011      1   20          3     4  -4.739464
# 25          70    16.9979  2011      1   21          4     1  -0.198152
# 26          75    11.0014  2011      1   21          4     2  -1.935282
# 27          80    19.9995  2011      1   21          4     3  -5.764981
# 28          87     6.0032  2011      1   21          4     4  -3.406674
# 52          48    19.9995  2011      1   22          5     4  -3.569444
# 53          44    15.0013  2011      1   22          5     6  -5.876126
# 54          44    19.0012  2011      1   22          5     7 -46.945889
# 55          44    22.0028  2011      1   22          5     8  -4.014722
# 74          62     8.9981  2011      1   23          6     3  -2.203824
# 75          57     7.0015  2011      1   23          6     5  -4.319355
# 76          57     7.0015  2011      1   23          6     6  -6.565665
# 77          58    11.0014  2011      1   23          6     7 -59.580177
# 78          62    11.0014  2011      1   23          6     8 -27.625048
# 93          41    15.0013  2011      1   23          6    23  -0.465204
# 95          45    12.9980  2011      1   24          0     1  -0.813862
# 96          45    16.9979  2011      1   24          0     3  -3.278405
# 97          48     8.9981  2011      1   24          0     4 -11.151542
# 118         69    11.0014  2011      1   25          1     1  -2.239100
# 119         69    15.0013  2011      1   25          1     2  -9.033051
# 120         74     7.0015  2011      1   25          1     4  -9.472185
# 141         65     8.9981  2011      1   26          2     1  -0.229759
# 142         69    12.9980  2011      1   26          2     2  -3.812818
# 148         93    19.0012  2011      1   26          2    10 -30.990829
# 149         93    22.0028  2011      1   26          2    11 -27.156809
# 150         93    22.0028  2011      1   26          2    12 -16.762125
# 151         93    22.0028  2011      1   26          2    13 -16.762125
# ...        ...        ...   ...    ...  ...        ...   ...        ...
# 3443        30     0.0000  2012      1   29          6     4  -4.978138
# 3467        51     8.9981  2012      1   30          0     4  -0.200822
# 3513        87     6.0032  2012      2   20          0     2  -1.846707
# 3516        52    27.9993  2012      2   20          0     6  -4.777178
# 3607        77    19.0012  2012      2   24          4     2  -3.898578
# 3633        42    22.0028  2012      2   25          5     4  -0.240051
# 4107        81    31.0009  2012      4   22          6    23 -35.531136
# 4109        87    23.9994  2012      4   23          0     1  -4.153739
# 4110        87    22.0028  2012      4   23          0     2  -3.716686
# 4111        81    19.0012  2012      4   23          0     3  -0.848675
# 4112        81    19.0012  2012      4   23          0     4 -12.282132
# 4113        81    19.0012  2012      4   23          0     5  -0.413133
# 4325        88    23.9994  2012      5   21          0     1  -0.936201
# 4326        94    16.9979  2012      5   21          0     2 -19.897591
# 4327        88    19.9995  2012      5   21          0     3  -6.430934
# 4328        88    19.9995  2012      5   21          0     4 -15.544998
# 4329        88    19.9995  2012      5   21          0     5  -2.027884
# 4350        83     7.0015  2012      5   22          1     2  -3.957726
# 4351        83     7.0015  2012      5   22          1     3  -4.507993
# 4352        88    11.0014  2012      5   22          1     4  -3.615231
# 4543        88     8.9981  2012      5   30          2     3  -4.105425
# 5142        83    11.0014  2012      8   20          0     2  -0.343964
# 5144        83     6.0032  2012      8   20          0     4 -14.889221
# 5621        88     0.0000  2012      9   28          4     1 -11.911075
# 5622        88    19.9995  2012      9   28          4     2 -11.508754
# 5624        88     7.0015  2012      9   28          4     4  -3.935430
# 5906        88    23.9994  2012     10   28          6    22 -16.126238
# 5907        94    23.9994  2012     10   28          6    23 -22.221630
# 6230        82    19.9995  2012     12   20          3    23  -0.718980
# 6372        87    19.9995  2012     12   26          2    23 -13.475777
#
# [231 rows x 15 columns]

# %%
df_test["count"] = df_test["count"].map(adjust_count)

# %%
df_test[['datetime','count']].to_csv('predicted_count.csv',index=False)

# %%
# RMSLE (Kaggle) Score
# Test 1: 0.62
